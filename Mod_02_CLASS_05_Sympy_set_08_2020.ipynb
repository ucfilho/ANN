# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN/blob/master/Mod_02_CLASS_05_Sympy_set_08_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

# %%
x = symbols('x')
y = symbols('y')

# %%
diff(cos(x), x)
# Out:
# -sin(x)

# %%
diff(x**2-y+x*cos(pi*x),x)
