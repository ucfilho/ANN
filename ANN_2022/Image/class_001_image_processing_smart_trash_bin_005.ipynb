# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN/blob/master/ANN_2022/Image/class_001_image_processing_smart_trash_bin_005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import random
import zipfile
from matplotlib import pyplot as plt

# %%
# !gdown --id 1L4mdCDBgybKqr5Wo-kqT8HXcBJ9HXqSX
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1L4mdCDBgybKqr5Wo-kqT8HXcBJ9HXqSX
# To: /content/trash_nov_22_2018.zip
# 100% 42.8M/42.8M [00:00<00:00, 162MB/s]

# %%
FILE='trash_nov_22_2018.zip'

# %%
archive = zipfile.ZipFile('trash_nov_22_2018.zip', 'r')
archive.extractall()

# %%
img_name=[]
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)

# %%
Img_Size = 80

# %%
X_test= []  
Y_test =[]
n = len(img_name)
i =0
for i in range(16):
  name = img_name[random.randrange(n)]
  Y_test.append(name)
  X_test.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))

# %%
plt.figure(figsize=(10, 10))

for i in range(16): 
  ax = plt.subplot(4, 4, i + 1)
  resized = cv2.resize(X_test[i], (Img_Size,Img_Size))
  plt.imshow(resized)
  plt.title(Y_test[i])
  plt.axis("off")
