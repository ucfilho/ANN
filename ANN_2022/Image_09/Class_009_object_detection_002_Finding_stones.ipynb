# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN/blob/master/ANN_2022/Image_09/Class_009_object_detection_002_Finding_stones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network find places where there are stones

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import zipfile
# %matplotlib inline

# %%
# !git clone https://github.com/ucfilho/Machine_Learning_DataSet
# %cd Machine_Learning_DataSet
# Out:
# Cloning into 'Machine_Learning_DataSet'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 172 (delta 32), reused 56 (delta 20), pack-reused 75
# Receiving objects: 100% (172/172), 58.49 MiB | 20.55 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/Machine_Learning_DataSet

# %%
# !gdown 1EMAqxWAIDJXqZv4qyAK-mDbx3X-uh7jp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EMAqxWAIDJXqZv4qyAK-mDbx3X-uh7jp
# To: /content/Machine_Learning_DataSet/find_stones_area.zip
# 100% 113M/113M [00:01<00:00, 72.6MB/s]

# %%
FILE='find_stones_area.zip'

# %%
archive = zipfile.ZipFile(FILE, 'r')
archive.extractall()

# %%
img_name=[]
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)

# %%
#img_name

# %%
stones2find = cv2.imread('20221103_143816quarter.jpg',0)

# %%
plt.figure(figsize=(15, 15))
plt.imshow(cv2.cvtColor(cv2.imread('20221103_143816quarter.jpg'), cv2.COLOR_BGR2RGB))

# %%
nrow, ncol = stones2find.shape
nrow, ncol
# Out:
# (4032, 1860)

# %%
size = 200
horiz = int(nrow/size)
vert = int(ncol/size)
segmentation = []
for i in range(horiz):
  h = i*size
  for j in range(vert):
    w = j*size
    img=np.zeros((size,size)).astype(np.int64)
    for ii in range(size):
      for jj in range(size):
        img[ii,jj] = stones2find[ii+h,jj+w]
    
    segmentation.append(img)



#plt.figure(figsize=(5,5))
#plt.imshow(img)

# %%
len(segmentation)
# Out:
# 180

# %%
horiz*vert
# Out:
# 180

# %%
plt.figure(figsize=(30, 30))
n = int(horiz*vert)
for i in range(n): 
  ax = plt.subplot(vert, horiz, i + 1)
  plt.imshow(segmentation[i], cmap="gray")
  #plt.title(i)
  plt.axis("off")

# %%
plt.figure(figsize=(30, 30))
n = int(horiz*vert)
for i in range(n): 
  ax = plt.subplot(horiz, vert, i + 1)
  plt.imshow(segmentation[i], cmap="gray")
  #plt.title(i)
  plt.axis("off")
