# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN/blob/master/ANN_2022/Image_09/Class_009_object_detection_003_Finding_stones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network find places where there are stones

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import zipfile
# %matplotlib inline

# %%
# !git clone https://github.com/ucfilho/Machine_Learning_DataSet
# %cd Machine_Learning_DataSet
# Out:
# fatal: destination path 'Machine_Learning_DataSet' already exists and is not an empty directory.
# /content/Machine_Learning_DataSet

# %%
# !gdown 1EMAqxWAIDJXqZv4qyAK-mDbx3X-uh7jp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EMAqxWAIDJXqZv4qyAK-mDbx3X-uh7jp
# To: /content/Machine_Learning_DataSet/find_stones_area.zip
# 100% 113M/113M [00:00<00:00, 303MB/s]

# %%
FILE='find_stones_area.zip'

# %%
archive = zipfile.ZipFile(FILE, 'r')
archive.extractall()

# %%
img_name=[]
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)

# %%
#img_name

# %%
# !git clone https://github.com/ucfilho/ANN #clonar do Github
# %cd ANN
# Out:
# fatal: destination path 'ANN' already exists and is not an empty directory.
# /content/Machine_Learning_DataSet/ANN

# %%
f1='john_mccarthy.png'
Img_Size = 400
img1 = cv2.imread(f1,0)

# %%
stones2find = cv2.imread('20221103_143816quarter.jpg',0)
stones2find = img1

# %%
plt.figure(figsize=(15, 15))
plt.imshow(stones2find, cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 541.5, 505.5, -0.5)

# %%
nrow, ncol = stones2find.shape
nrow, ncol
# Out:
# (506, 542)

# %%
size = 20
horiz = int(nrow/size)
vert = int(ncol/size)
segmentation = []
for i in range(horiz):
  h = i*size
  for j in range(vert):
    w = j*size
    img=np.zeros((size,size)).astype(np.int64)
    for ii in range(size):
      for jj in range(size):
        img[ii,jj] = stones2find[ii+h,jj+w]
    
    segmentation.append(img)



#plt.figure(figsize=(5,5))
#plt.imshow(img)

# %%
len(segmentation)
# Out:
# 675

# %%
horiz*vert
# Out:
# 675

# %%
plt.figure(figsize=(30, 30))
n = int(horiz*vert)
for i in range(n): 
  ax = plt.subplot(horiz, vert, i + 1)
  plt.imshow(segmentation[i], cmap="gray")
  #plt.title(i)
  plt.axis("off")
