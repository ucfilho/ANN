# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN/blob/master/Imagem_carrega_dez_12_2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import os 
import cv2

# %%
from google.colab import files
def getLocalFiles():
    _files = files.upload()
    if len(_files) >0:
       for k,v in _files.items():
         open(k,'wb').write(v)
getLocalFiles()
# Out:
#      <input type="file" id="files-3c4d0eb8-5f21-48e1-b095-2af02da90df0" name="files[]" multiple disabled />
#      <output id="result-3c4d0eb8-5f21-48e1-b095-2af02da90df0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imagem_teste.zip to imagem_teste (1).zip

# %%
print("Path at terminal when executing this file")
print(os.getcwd() + "\n")
# Out:
# Path at terminal when executing this file
# /content

# %%
import zipfile
file_name = zipfile.ZipFile('imagem_teste.zip', 'r')
file_name.extractall()

# %%
img=cv2.imread("imagem_04.png")
plt.axis("off")
plt.imshow(img)
plt.show()

# %%
img=cv2.imread("imagem_04.png")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(RGB_img)
plt.show()

# %% [markdown]
# OpenCV uses BGR as its default colour order for images, matplotlib uses RGB

# %%
FILE='imagem_teste.zip'
img_name=[]
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)
print(img_name)
# Out:
# ['imagem_01.png', 'imagem_02.png', 'imagem_03.png', 'imagem_04.png', 'imagem_05.png', 'imagem_06.png']

# %%
for i in img_name:
  img=cv2.imread(i)
  RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.axis("off")
  plt.imshow(RGB_img)
  plt.show()

# %% [markdown]
# # Lena Söderberg

# %% [markdown]
# https://medium.com/five-guys-facts/lenna-e802b18d9ddc
