# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN/blob/master/DE_OPTIM_Cauchy_Insight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
############################### Importar códigos

# !git clone https://github.com/ucfilho/optim_raianars_Insight/ #clonar do Github
# Out:
# fatal: destination path 'optim_raianars_Insight' already exists and is not an empty directory.

# %%
# %cd optim_raianars_Insight
#!ls
# Out:
# /content/optim_raianars_Insight

# %%
############################### Importar bibliotecas e iniciar a contagem do tempo
import time
import matplotlib.pyplot as plt
import numpy as np
import random
from scipy import optimize
import de_bounds_matriz
import de_soma_Insight
###############################

# %%
def fobj_de(x):
  global MAX,MIN, mut, crossp, its,Fun,X,SOMA,TOTAL,ITE,PARTIC
  popsize=len(PARTIC)
  x=PARTIC
  ind_mut=ITE-1
  ind_crossp=2*ITE-1
  for k in range(ITE):
    ind_mut=ind_mut+1
    ind_crossp=ind_crossp+1
    NPAR=np.copy(int(x[popsize-1,k]))
    mut=np.copy(x[popsize-1,ind_mut])
    crossp=np.copy(x[popsize-1,ind_crossp])
    X,BEST,FOBEST,XY,BEST_XY,SOMA= de_soma_Insight.de(MAX,MIN, mut, crossp, 
                                                            NPAR, its,Fun,X,SOMA,
                                                            TOTAL)
    
  return FOBEST

# %%
############################### DADOS DE ENTRADA 
RUNS=1 #NÚMERO DE RODADAS
#mut=0.8
#crossp=0.7
  ############################### Função
import Function

'''
Fun=Function.Rosenbrock
dim=30
MAX=np.repeat(10,dim)
MIN=np.repeat(-10,dim)

  #Global optimum: f(xi)= 0
'''
'''
dim=30
Fun=Function.Sphere
MAX=np.repeat(5.12,dim)
MIN=np.repeat(-5.12,dim)
  # f(x)=0 x=(0,0) [-5.12,5.12]
'''
#'''
dim=2
Fun=Function.Schwefel
MAX=np.repeat(500,dim)
MIN=np.repeat(-500,dim)
  #Global optimum: f(xi)= 0 for xi = 420.968746 for i=1,...,n  ;  xi in [-500,500]  
#'''
'''
dim=30
Fun=Function.Rastrigin
MAX=np.repeat(5.12,dim)
MIN=np.repeat(-5.12,dim)
  # f(x)=0 x=(0,0) [-5.12,5.12]
'''
'''
dim=30
Fun=Function.Sum_of_different_powers
MAX=np.repeat(1,dim)
MIN=np.repeat(-1,dim)
  # f(x)=0 x=(0,0)
'''
'''  
dim=30
Fun=Function.Ackley
MAX=np.repeat(32,dim)
MIN=np.repeat(-32,dim)
 # f(x)=0 x=(0,0) [-32, 32]
'''
'''  
dim=30
Fun=Function.Michalewicz
MAX=np.repeat(np.pi,dim)
MIN=np.repeat(0,dim)
 #fx=-9.66015 p/ d=10 [0,pi]
'''
'''  
dim=30
Fun=Function.
MAX=np.repeat(1,dim)
MIN=np.repeat(-1,dim)
'''

PAR=len(MAX) #NUM DE PARAMETROS A SER OTIMIZADOS

# %%
def uniform_proposal(x, delta=2.0):
    return np.random.uniform(x - delta, x + delta)

def metropolis_sampler(p, nsamples, proposal=uniform_proposal):
    x = 1 # start somewhere

    for i in range(nsamples):
        trial = proposal(x) # random neighbour from the proposal distribution
        acceptance = p(trial)/p(x)

        # accept the move conditionally
        if np.random.uniform() < acceptance:
            x = trial

        yield x

def cauchy(x, mu, gamma):
    return 1./(np.pi*gamma*(1.+((x-mu)/gamma)**2))

# %%
##################################### IMPORTAR MÓDULOS


maxiter=10
popsize=10
#NMAX=1000 # maximo tamanho da populacao
NMAX=popsize
dimensions=len(MAX)

start_time = time.time() #INICIALIZA CONTAGEM DO TEMPO
its=10 # quantas vezes vai usar o NPAR antes de alterar de novo
ITE=10 # PONTOS quantas vezes vai alteral NPAR 
#PARTIC=[10,80,10,400,100,100,100,100,100,100]
#ITE=50 # so para testar

#TOTAL=7*dim*its*ITE
TOTAL=10*dim*its*ITE


p=int(TOTAL/its/ITE) 



for i in range(RUNS):
  SOMA=0
  #pop = np.random.rand(NMAX, dimensions)



  
  
  #X = MIN + pop * diff
    
  PONTOS=ITE # DIVISOES DA POPULACAO
 
 ############################################################
  #bounds=[(5*dim, 15*dim)] * PONTOS # ITE
  #bounds=[(3*dim, 12*dim)] * PONTOS # ITE
  #bounds=[(4*dim, 16*dim)] * PONTOS
  
  # nao pode ser assim pq o bounds vale p o DE nao dos parametros
  #p=int(TOTAL/its/ITE) 
  bounds=[(p, p)] * PONTOS
  #bounds=[]
  #for k in range(dim):
  #  bounds.append((MIN[k], MAX[k]))
  # print("=========bounds=",bounds)
    


  '''
  #Geral
  new_mut=(0,1)
  new_crossp=(0,1)
  '''
  #'''
  #Multimodal Separável 
  new_mut=(0.5,1)
  new_crossp=(0,0.5)
  #'''
  '''
  #Multimodal Não Separável 
  new_mut=(0.5,1)
  new_crossp=(0.5,1)
  '''
  '''
  ##### Unimodal Separável
  new_mut=(0,0.5)
  new_crossp=(0,0.5)
  '''
  '''
  ##### Unimodal Não Separável
  new_mut=(0,0.5)
  new_crossp=(0.5,1)
  '''
 ############################################################ 
  # nao pode ser assim pq o bounds vale p o DE nao dos parametros
  ''' '''
  for j in range(PONTOS):
    bounds.append(new_mut)
    
  for j in range(PONTOS):
    bounds.append(new_crossp)

  #print("=========bounds=",bounds)

  new_mut=(0.5,1)
  new_crossp=(0,0.5)
  Fr=np.zeros(its)
  Cr=np.zeros(its)

  Cr=0;Fr=0;
  PARTIC=np.zeros((popsize,its*3))
  #pop = np.random.rand(NPAR, PAR)
  pop = np.random.rand(popsize, PAR)
  diff=np.zeros(PAR)
  for ii in range(PAR):
    diff[ii] = MAX[ii]-MIN[ii]
  X = MIN + pop * diff
  pp = lambda x: cauchy(x, 0.5, 0.3)
  samples = list(metropolis_sampler(pp, 10000))
  samples=np.array(samples)
  samples = samples[(samples>0) & (samples<1)]
  sampling = random.choices(samples, k=(its*2*popsize))
  a=list(range(0,2*its*popsize))
  #print(a)
  b=[];c=[]
  for i in range(its*popsize):
    b.append(a[i])
  for i in range(its*popsize,2*its*popsize):
    c.append(a[i])
    cont=-1
  for k in range(popsize):
    for i in range(its):
      cont=cont+1
      ii=b[cont];jj=c[cont]
      Cr=new_crossp[0]+(new_crossp[1]-new_crossp[0])*sampling[ii]
      Fr=new_mut[0]+(new_mut[1]-new_mut[0])*sampling[jj]
      PARTIC[k,i]=p
      PARTIC[k,i+10]=Fr
      PARTIC[k,i+20]=Cr
  #print("=========PARTIC=",PARTIC)
  mut=0.5;  crossp=0.5;popsize=len(PARTIC);
  X,BEST,FOBEST,XY,BEST_XY= de_bounds_matriz.de(bounds, mut, 
                                                   crossp,popsize, maxiter,
                                                   fobj_de,PARTIC)
  


  print('OTIMIZAÇÃO DE_','maxiter=',maxiter,'_ popsize=', popsize,'_ bounds=',
        bounds[0],'_F',new_mut,'_Cr',new_crossp,'_ TOTAL=',TOTAL,'_ Dim=', 
        PAR,"_Min/Max=",MIN[0],"/",MAX[0],'_',Fun.__name__)
  print('otimo FOBEST=',FOBEST)
  print("BEST=",BEST)
  print("Soma= ",SOMA) 
#print("GlobalParam e Solucao:", BEST,"Função=",FOBEST)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-98ec5ed4fb92> in <module>()
#     123   X,BEST,FOBEST,XY,BEST_XY= de_bounds_matriz.de(bounds, mut,
#     124                                                    crossp,popsize, maxiter,
# --> 125                                                    fobj_de,PARTIC)
#     126
#     127
#
# /content/optim_raianars_Insight/de_bounds_matriz.py in de(bounds, mut, crossp, popsize, its, fobj, X)
#      12     MIN[k]=bounds[k][0]
#      13
# ---> 14   fitness = np.asarray([fobj(ind) for ind in X])
#      15   best_idx = np.argmin(fitness)
#      16   best = X[best_idx]
#
# /content/optim_raianars_Insight/de_bounds_matriz.py in <listcomp>(.0)
#      12     MIN[k]=bounds[k][0]
#      13
# ---> 14   fitness = np.asarray([fobj(ind) for ind in X])
#      15   best_idx = np.argmin(fitness)
#      16   best = X[best_idx]
#
# <ipython-input-4-f11eea5d6dc4> in fobj_de(x)
#      13     X,BEST,FOBEST,XY,BEST_XY,SOMA= de_soma_Insight.de(MAX,MIN, mut, crossp,
#      14                                                             NPAR, its,Fun,X,SOMA,
# ---> 15                                                             TOTAL)
#      16
#      17   return FOBEST
#
# /content/optim_raianars_Insight/de_soma_Insight.py in de(MAX, MIN, mut, crossp, popsize, its, fobj, X, SOMA, TOTAL)
#      10   for i in range(popsize):
#      11     for j in range(Num):
# ---> 12         X[i,j]=np.copy(XOLD[i,j])
#      13
#      14
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
print(Xresp)

# %%
print(max(sampling))

# %%
print(len(samples))

# %%
print(X.shape)

# %%
BEST

# %%
print(TOTAL)

# %%
print(PARTIC)

# %%
TIME = (time.time() - start_time)
print(TIME/60,'minutos')

# %%
BEST=BEST.tolist()
print('PARTIC=[',end = '')
for i in range(len(BEST)):
  if i<ITE:
    print(int(BEST[i]),',',end = '')
  else:
    print(BEST[i],',',end = '')
print(']',end = '')
